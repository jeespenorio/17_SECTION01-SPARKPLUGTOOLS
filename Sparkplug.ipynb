# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Worker 335'



 

]

oem_numbers = ['3084980']

# Range of years
years = list(range(1999, 2000))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#       Make       Model Vendor Code                   Vendor Name        MPN  \
# 0  POLARIS  Worker 335        NACH  NACHMAN INTERNATIONAL CO.LTD  AT-01320A
#
#   AD Item Number                                     Vendor Notes  REF#  \
# 0         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>
#
#       OEM#  Year
# 0  3084980  1999

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\1.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Sportsman 335'



 

]

oem_numbers = ['3084980']

# Range of years
years = list(range(1999, 2001))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#       Make          Model Vendor Code                   Vendor Name  \
# 0  POLARIS  Sportsman 335        NACH  NACHMAN INTERNATIONAL CO.LTD
# 1  POLARIS  Sportsman 335        NACH  NACHMAN INTERNATIONAL CO.LTD
#
#          MPN AD Item Number                                     Vendor Notes  \
# 0  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 1  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
#
#    REF#     OEM#  Year
# 0  <NA>  3084980  1999
# 1  <NA>  3084980  2000

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\2.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Sportsman 400'



 

]

oem_numbers = ['3084980']

# Range of years
years = list(range(2001, 2006))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#       Make          Model Vendor Code                   Vendor Name  \
# 0  POLARIS  Sportsman 400        NACH  NACHMAN INTERNATIONAL CO.LTD
# 1  POLARIS  Sportsman 400        NACH  NACHMAN INTERNATIONAL CO.LTD
# 2  POLARIS  Sportsman 400        NACH  NACHMAN INTERNATIONAL CO.LTD
# 3  POLARIS  Sportsman 400        NACH  NACHMAN INTERNATIONAL CO.LTD
# 4  POLARIS  Sportsman 400        NACH  NACHMAN INTERNATIONAL CO.LTD
#
#          MPN AD Item Number                                     Vendor Notes  \
# 0  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 1  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 2  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 3  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 4  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
#
#    REF#     OEM#  Year
# 0  <NA>  3084980  2001
# 1  <NA>  3084980  2002
# 2  <NA>  3084980  2003
# 3  <NA>  3084980  2004
# 4  <NA>  3084980  2005

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\3.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Sportsman 400 HO',
'Sportsman 400 4x4'



 

]

oem_numbers = ['3084980']

# Range of years
years = list(range(2008, 2014))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#        Make              Model Vendor Code                   Vendor Name  \
# 0   POLARIS   Sportsman 400 HO        NACH  NACHMAN INTERNATIONAL CO.LTD
# 1   POLARIS  Sportsman 400 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 2   POLARIS   Sportsman 400 HO        NACH  NACHMAN INTERNATIONAL CO.LTD
# 3   POLARIS  Sportsman 400 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 4   POLARIS   Sportsman 400 HO        NACH  NACHMAN INTERNATIONAL CO.LTD
# 5   POLARIS  Sportsman 400 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 6   POLARIS   Sportsman 400 HO        NACH  NACHMAN INTERNATIONAL CO.LTD
# 7   POLARIS  Sportsman 400 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 8   POLARIS   Sportsman 400 HO        NACH  NACHMAN INTERNATIONAL CO.LTD
# 9   POLARIS  Sportsman 400 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 10  POLARIS   Sportsman 400 HO        NACH  NACHMAN INTERNATIONAL CO.LTD
# 11  POLARIS  Sportsman 400 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
#
#           MPN AD Item Number                                     Vendor Notes  \
# 0   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 1   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 2   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 3   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 4   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 5   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 6   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 7   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 8   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 9   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 10  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 11  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
#
#     REF#     OEM#  Year
# 0   <NA>  3084980  2008
# 1   <NA>  3084980  2008
# 2   <NA>  3084980  2009
# 3   <NA>  3084980  2009
# 4   <NA>  3084980  2010
# 5   <NA>  3084980  2010
# 6   <NA>  3084980  2011
# 7   <NA>  3084980  2011
# 8   <NA>  3084980  2012
# 9   <NA>  3084980  2012
# 10  <NA>  3084980  2013
# 11  <NA>  3084980  2013

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\4.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Hawkeye 2x4'




 

]

oem_numbers = ['3084980']

# Range of years
years = list(range(2011, 2015))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#       Make        Model Vendor Code                   Vendor Name        MPN  \
# 0  POLARIS  Hawkeye 2x4        NACH  NACHMAN INTERNATIONAL CO.LTD  AT-01320A
# 1  POLARIS  Hawkeye 2x4        NACH  NACHMAN INTERNATIONAL CO.LTD  AT-01320A
# 2  POLARIS  Hawkeye 2x4        NACH  NACHMAN INTERNATIONAL CO.LTD  AT-01320A
# 3  POLARIS  Hawkeye 2x4        NACH  NACHMAN INTERNATIONAL CO.LTD  AT-01320A
#
#   AD Item Number                                     Vendor Notes  REF#  \
# 0         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>
# 1         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>
# 2         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>
# 3         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>
#
#       OEM#  Year
# 0  3084980  2011
# 1  3084980  2012
# 2  3084980  2013
# 3  3084980  2014

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\5.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'XPEDITION 425'




 

]

oem_numbers = ['3084980']

# Range of years
years = list(range(2000, 2003))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#       Make          Model Vendor Code                   Vendor Name  \
# 0  POLARIS  XPEDITION 425        NACH  NACHMAN INTERNATIONAL CO.LTD
# 1  POLARIS  XPEDITION 425        NACH  NACHMAN INTERNATIONAL CO.LTD
# 2  POLARIS  XPEDITION 425        NACH  NACHMAN INTERNATIONAL CO.LTD
#
#          MPN AD Item Number                                     Vendor Notes  \
# 0  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 1  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 2  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
#
#    REF#     OEM#  Year
# 0  <NA>  3084980  2000
# 1  <NA>  3084980  2001
# 2  <NA>  3084980  2002

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\6.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Sportsman 450'




 

]

oem_numbers = ['3084980']

# Range of years
years = list(range(2006, 2008))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#       Make          Model Vendor Code                   Vendor Name  \
# 0  POLARIS  Sportsman 450        NACH  NACHMAN INTERNATIONAL CO.LTD
# 1  POLARIS  Sportsman 450        NACH  NACHMAN INTERNATIONAL CO.LTD
#
#          MPN AD Item Number                                     Vendor Notes  \
# 0  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 1  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
#
#    REF#     OEM#  Year
# 0  <NA>  3084980  2006
# 1  <NA>  3084980  2007

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\7.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Xplorer 500 4x4'




 

]

oem_numbers = ['3084980']

# Range of years
years = list(range(1997,1998))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#       Make            Model Vendor Code                   Vendor Name  \
# 0  POLARIS  Xplorer 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
#
#          MPN AD Item Number                                     Vendor Notes  \
# 0  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
#
#    REF#     OEM#  Year
# 0  <NA>  3084980  1997

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\8.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Magnum 500 4x4',
'Scrambler 500 4x4'





 

]

oem_numbers = ['3084980']

# Range of years
years = list(range(2002,2003))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#       Make              Model Vendor Code                   Vendor Name  \
# 0  POLARIS     Magnum 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 1  POLARIS  Scrambler 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
#
#          MPN AD Item Number                                     Vendor Notes  \
# 0  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 1  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
#
#    REF#     OEM#  Year
# 0  <NA>  3084980  2002
# 1  <NA>  3084980  2002

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\9.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Scrambler 500 2x4'





 

]

oem_numbers = ['3084980']

# Range of years
years = list(range(1997,2003))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#       Make              Model Vendor Code                   Vendor Name  \
# 0  POLARIS  Scrambler 500 2x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 1  POLARIS  Scrambler 500 2x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 2  POLARIS  Scrambler 500 2x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 3  POLARIS  Scrambler 500 2x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 4  POLARIS  Scrambler 500 2x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 5  POLARIS  Scrambler 500 2x4        NACH  NACHMAN INTERNATIONAL CO.LTD
#
#          MPN AD Item Number                                     Vendor Notes  \
# 0  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 1  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 2  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 3  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 4  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 5  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
#
#    REF#     OEM#  Year
# 0  <NA>  3084980  1997
# 1  <NA>  3084980  1998
# 2  <NA>  3084980  1999
# 3  <NA>  3084980  2000
# 4  <NA>  3084980  2001
# 5  <NA>  3084980  2002

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\10.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Sportsman 500 4x4',
 'Sportsman 500 6x6',
 'Sportsman 500 EFI Touring',
 'Sportsman 500 EFI X2',
 'Sportsman 500 HO',
 'Sportsman 500 EFI',
 'Sportsman 500 EFI Deluxe',
 'Sportsman 500 EFI X2 Deluxe',
 'Sportsman 500 RSE',
 'Sportsman 500 HO RSE',
 'Sportsman 500 HO Touring',
 'Sportsman 500 HO Polaris Pursuite LE',
 'Sportsman 500 HO DUSE'

]

oem_numbers = ['3084980']

# Range of years
years = list(range(1997,2003))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#        Make                                 Model Vendor Code  \
# 0   POLARIS                     Sportsman 500 4x4        NACH
# 1   POLARIS                     Sportsman 500 6x6        NACH
# 2   POLARIS             Sportsman 500 EFI Touring        NACH
# 3   POLARIS                  Sportsman 500 EFI X2        NACH
# 4   POLARIS                      Sportsman 500 HO        NACH
# ..      ...                                   ...         ...
# 73  POLARIS                     Sportsman 500 RSE        NACH
# 74  POLARIS                  Sportsman 500 HO RSE        NACH
# 75  POLARIS              Sportsman 500 HO Touring        NACH
# 76  POLARIS  Sportsman 500 HO Polaris Pursuite LE        NACH
# 77  POLARIS                 Sportsman 500 HO DUSE        NACH
#
#                      Vendor Name        MPN AD Item Number  \
# 0   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 1   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 2   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 3   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 4   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# ..                           ...        ...            ...
# 73  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 74  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 75  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 76  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 77  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
#
#                                        Vendor Notes  REF#     OEM#  Year
# 0   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  1997
# 1   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  1997
# 2   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  1997
# 3   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  1997
# 4   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  1997
# ..                                              ...   ...      ...   ...
# 73  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2002
# 74  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2002
# 75  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2002
# 76  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2002
# 77  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2002
#
# [78 rows x 10 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\11.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Worker 500',
'Sportsman 500 RSE'


]

oem_numbers = ['3084980']

# Range of years
years = list(range(1999,2002))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#       Make              Model Vendor Code                   Vendor Name  \
# 0  POLARIS         Worker 500        NACH  NACHMAN INTERNATIONAL CO.LTD
# 1  POLARIS  Sportsman 500 RSE        NACH  NACHMAN INTERNATIONAL CO.LTD
# 2  POLARIS         Worker 500        NACH  NACHMAN INTERNATIONAL CO.LTD
# 3  POLARIS  Sportsman 500 RSE        NACH  NACHMAN INTERNATIONAL CO.LTD
# 4  POLARIS         Worker 500        NACH  NACHMAN INTERNATIONAL CO.LTD
# 5  POLARIS  Sportsman 500 RSE        NACH  NACHMAN INTERNATIONAL CO.LTD
#
#          MPN AD Item Number                                     Vendor Notes  \
# 0  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 1  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 2  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 3  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 4  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 5  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
#
#    REF#     OEM#  Year
# 0  <NA>  3084980  1999
# 1  <NA>  3084980  1999
# 2  <NA>  3084980  2000
# 3  <NA>  3084980  2000
# 4  <NA>  3084980  2001
# 5  <NA>  3084980  2001

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\12.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Magnum 500 4x4'



]

oem_numbers = ['3084980']

# Range of years
years = list(range(2000,2004))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#       Make           Model Vendor Code                   Vendor Name  \
# 0  POLARIS  Magnum 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 1  POLARIS  Magnum 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 2  POLARIS  Magnum 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 3  POLARIS  Magnum 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
#
#          MPN AD Item Number                                     Vendor Notes  \
# 0  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 1  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 2  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 3  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
#
#    REF#     OEM#  Year
# 0  <NA>  3084980  2000
# 1  <NA>  3084980  2001
# 2  <NA>  3084980  2002
# 3  <NA>  3084980  2003

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\13.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Scrambler 500 4x4'



]

oem_numbers = ['3084980']

# Range of years
years = list(range(2001,2013))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#        Make              Model Vendor Code                   Vendor Name  \
# 0   POLARIS  Scrambler 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 1   POLARIS  Scrambler 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 2   POLARIS  Scrambler 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 3   POLARIS  Scrambler 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 4   POLARIS  Scrambler 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 5   POLARIS  Scrambler 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 6   POLARIS  Scrambler 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 7   POLARIS  Scrambler 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 8   POLARIS  Scrambler 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 9   POLARIS  Scrambler 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 10  POLARIS  Scrambler 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 11  POLARIS  Scrambler 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
#
#           MPN AD Item Number                                     Vendor Notes  \
# 0   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 1   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 2   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 3   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 4   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 5   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 6   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 7   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 8   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 9   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 10  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 11  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
#
#     REF#     OEM#  Year
# 0   <NA>  3084980  2001
# 1   <NA>  3084980  2002
# 2   <NA>  3084980  2003
# 3   <NA>  3084980  2004
# 4   <NA>  3084980  2005
# 5   <NA>  3084980  2006
# 6   <NA>  3084980  2007
# 7   <NA>  3084980  2008
# 8   <NA>  3084980  2009
# 9   <NA>  3084980  2010
# 10  <NA>  3084980  2011
# 11  <NA>  3084980  2012

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\14.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Sportsman 500 HO'



]

oem_numbers = ['3084980']

# Range of years
years = list(range(2001,2014))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#        Make             Model Vendor Code                   Vendor Name  \
# 0   POLARIS  Sportsman 500 HO        NACH  NACHMAN INTERNATIONAL CO.LTD
# 1   POLARIS  Sportsman 500 HO        NACH  NACHMAN INTERNATIONAL CO.LTD
# 2   POLARIS  Sportsman 500 HO        NACH  NACHMAN INTERNATIONAL CO.LTD
# 3   POLARIS  Sportsman 500 HO        NACH  NACHMAN INTERNATIONAL CO.LTD
# 4   POLARIS  Sportsman 500 HO        NACH  NACHMAN INTERNATIONAL CO.LTD
# 5   POLARIS  Sportsman 500 HO        NACH  NACHMAN INTERNATIONAL CO.LTD
# 6   POLARIS  Sportsman 500 HO        NACH  NACHMAN INTERNATIONAL CO.LTD
# 7   POLARIS  Sportsman 500 HO        NACH  NACHMAN INTERNATIONAL CO.LTD
# 8   POLARIS  Sportsman 500 HO        NACH  NACHMAN INTERNATIONAL CO.LTD
# 9   POLARIS  Sportsman 500 HO        NACH  NACHMAN INTERNATIONAL CO.LTD
# 10  POLARIS  Sportsman 500 HO        NACH  NACHMAN INTERNATIONAL CO.LTD
# 11  POLARIS  Sportsman 500 HO        NACH  NACHMAN INTERNATIONAL CO.LTD
# 12  POLARIS  Sportsman 500 HO        NACH  NACHMAN INTERNATIONAL CO.LTD
#
#           MPN AD Item Number                                     Vendor Notes  \
# 0   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 1   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 2   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 3   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 4   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 5   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 6   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 7   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 8   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 9   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 10  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 11  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 12  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
#
#     REF#     OEM#  Year
# 0   <NA>  3084980  2001
# 1   <NA>  3084980  2002
# 2   <NA>  3084980  2003
# 3   <NA>  3084980  2004
# 4   <NA>  3084980  2005
# 5   <NA>  3084980  2006
# 6   <NA>  3084980  2007
# 7   <NA>  3084980  2008
# 8   <NA>  3084980  2009
# 9   <NA>  3084980  2010
# 10  <NA>  3084980  2011
# 11  <NA>  3084980  2012
# 12  <NA>  3084980  2013

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\15.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Scrambler 500 2x4'



]

oem_numbers = ['3084980']

# Range of years
years = list(range(2007,2010))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#       Make              Model Vendor Code                   Vendor Name  \
# 0  POLARIS  Scrambler 500 2x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 1  POLARIS  Scrambler 500 2x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 2  POLARIS  Scrambler 500 2x4        NACH  NACHMAN INTERNATIONAL CO.LTD
#
#          MPN AD Item Number                                     Vendor Notes  \
# 0  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 1  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 2  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
#
#    REF#     OEM#  Year
# 0  <NA>  3084980  2007
# 1  <NA>  3084980  2008
# 2  <NA>  3084980  2009

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\16.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Sportsman 500 HO Touring'



]

oem_numbers = ['3084980']

# Range of years
years = list(range(2010,2014))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#       Make                     Model Vendor Code  \
# 0  POLARIS  Sportsman 500 HO Touring        NACH
# 1  POLARIS  Sportsman 500 HO Touring        NACH
# 2  POLARIS  Sportsman 500 HO Touring        NACH
# 3  POLARIS  Sportsman 500 HO Touring        NACH
#
#                     Vendor Name        MPN AD Item Number  \
# 0  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 1  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 2  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 3  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
#
#                                       Vendor Notes  REF#     OEM#  Year
# 0  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2010
# 1  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2011
# 2  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2012
# 3  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2013

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\17.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Sportsman Forest 500'



]

oem_numbers = ['3084980']

# Range of years
years = list(range(2011,2014))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#       Make                 Model Vendor Code                   Vendor Name  \
# 0  POLARIS  Sportsman Forest 500        NACH  NACHMAN INTERNATIONAL CO.LTD
# 1  POLARIS  Sportsman Forest 500        NACH  NACHMAN INTERNATIONAL CO.LTD
# 2  POLARIS  Sportsman Forest 500        NACH  NACHMAN INTERNATIONAL CO.LTD
#
#          MPN AD Item Number                                     Vendor Notes  \
# 0  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 1  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 2  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
#
#    REF#     OEM#  Year
# 0  <NA>  3084980  2011
# 1  <NA>  3084980  2012
# 2  <NA>  3084980  2013

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\18.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Ranger 6x6 500'



]

oem_numbers = ['3084980']

# Range of years
years = list(range(1999,2000))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#       Make           Model Vendor Code                   Vendor Name  \
# 0  POLARIS  Ranger 6x6 500        NACH  NACHMAN INTERNATIONAL CO.LTD
#
#          MPN AD Item Number                                     Vendor Notes  \
# 0  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
#
#    REF#     OEM#  Year
# 0  <NA>  3084980  1999

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\19.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Sportsman 500 6x6',
'Ranger 6x6 500'




]

oem_numbers = ['3084980']

# Range of years
years = list(range(2002,2003))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#       Make              Model Vendor Code                   Vendor Name  \
# 0  POLARIS  Sportsman 500 6x6        NACH  NACHMAN INTERNATIONAL CO.LTD
# 1  POLARIS     Ranger 6x6 500        NACH  NACHMAN INTERNATIONAL CO.LTD
#
#          MPN AD Item Number                                     Vendor Notes  \
# 0  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 1  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
#
#    REF#     OEM#  Year
# 0  <NA>  3084980  2002
# 1  <NA>  3084980  2002

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\20.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Magnum 325 2x4',
 'Magnum 325 4x4',
 'Magnum 330 2x4',
 'Magnum 330 4x4',
 'Magnum 425 2x4',
 'Magnum 425 4x4',
 'Magnum 425 6x6',
 'Magnum 500 2x4',
 'Magnum 500 4x4'




]

oem_numbers = ['3084980']

# Range of years
years = list(range(1995, 2003))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#        Make           Model Vendor Code                   Vendor Name  \
# 0   POLARIS  Magnum 325 2x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 1   POLARIS  Magnum 325 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 2   POLARIS  Magnum 330 2x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 3   POLARIS  Magnum 330 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 4   POLARIS  Magnum 425 2x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# ..      ...             ...         ...                           ...
# 67  POLARIS  Magnum 425 2x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 68  POLARIS  Magnum 425 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 69  POLARIS  Magnum 425 6x6        NACH  NACHMAN INTERNATIONAL CO.LTD
# 70  POLARIS  Magnum 500 2x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 71  POLARIS  Magnum 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
#
#           MPN AD Item Number                                     Vendor Notes  \
# 0   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 1   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 2   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 3   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 4   AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# ..        ...            ...                                              ...
# 67  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 68  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 69  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 70  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 71  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
#
#     REF#     OEM#  Year
# 0   <NA>  3084980  1995
# 1   <NA>  3084980  1995
# 2   <NA>  3084980  1995
# 3   <NA>  3084980  1995
# 4   <NA>  3084980  1995
# ..   ...      ...   ...
# 67  <NA>  3084980  2002
# 68  <NA>  3084980  2002
# 69  <NA>  3084980  2002
# 70  <NA>  3084980  2002
# 71  <NA>  3084980  2002
#
# [72 rows x 10 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\21.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Magnum 425 6x6'





]

oem_numbers = ['3084980']

# Range of years
years = list(range(1996, 1998))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#       Make           Model Vendor Code                   Vendor Name  \
# 0  POLARIS  Magnum 425 6x6        NACH  NACHMAN INTERNATIONAL CO.LTD
# 1  POLARIS  Magnum 425 6x6        NACH  NACHMAN INTERNATIONAL CO.LTD
#
#          MPN AD Item Number                                     Vendor Notes  \
# 0  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 1  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
#
#    REF#     OEM#  Year
# 0  <NA>  3084980  1996
# 1  <NA>  3084980  1997

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\22.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Big Boss 500 6x6',
'Sportsman 800 EFI 6x6 Big Boss',
'Sportsman 800 6x6 Big Boss',
'Sportsman 570 Big Boss 6x6 EPS'





]

oem_numbers = ['3084980']

# Range of years
years = list(range(1998, 2003))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#        Make                           Model Vendor Code  \
# 0   POLARIS                Big Boss 500 6x6        NACH
# 1   POLARIS  Sportsman 800 EFI 6x6 Big Boss        NACH
# 2   POLARIS      Sportsman 800 6x6 Big Boss        NACH
# 3   POLARIS  Sportsman 570 Big Boss 6x6 EPS        NACH
# 4   POLARIS                Big Boss 500 6x6        NACH
# 5   POLARIS  Sportsman 800 EFI 6x6 Big Boss        NACH
# 6   POLARIS      Sportsman 800 6x6 Big Boss        NACH
# 7   POLARIS  Sportsman 570 Big Boss 6x6 EPS        NACH
# 8   POLARIS                Big Boss 500 6x6        NACH
# 9   POLARIS  Sportsman 800 EFI 6x6 Big Boss        NACH
# 10  POLARIS      Sportsman 800 6x6 Big Boss        NACH
# 11  POLARIS  Sportsman 570 Big Boss 6x6 EPS        NACH
# 12  POLARIS                Big Boss 500 6x6        NACH
# 13  POLARIS  Sportsman 800 EFI 6x6 Big Boss        NACH
# 14  POLARIS      Sportsman 800 6x6 Big Boss        NACH
# 15  POLARIS  Sportsman 570 Big Boss 6x6 EPS        NACH
# 16  POLARIS                Big Boss 500 6x6        NACH
# 17  POLARIS  Sportsman 800 EFI 6x6 Big Boss        NACH
# 18  POLARIS      Sportsman 800 6x6 Big Boss        NACH
# 19  POLARIS  Sportsman 570 Big Boss 6x6 EPS        NACH
#
#                      Vendor Name        MPN AD Item Number  \
# 0   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 1   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 2   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 3   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 4   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 5   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 6   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 7   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 8   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 9   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 10  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 11  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 12  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 13  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 14  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 15  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 16  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 17  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 18  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 19  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
#
#                                        Vendor Notes  REF#     OEM#  Year
# 0   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  1998
# 1   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  1998
# 2   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  1998
# 3   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  1998
# 4   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  1999
# 5   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  1999
# 6   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  1999
# 7   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  1999
# 8   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2000
# 9   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2000
# 10  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2000
# 11  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2000
# 12  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2001
# 13  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2001
# 14  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2001
# 15  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2001
# 16  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2002
# 17  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2002
# 18  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2002
# 19  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2002

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\23.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Big Boss 500 6x6'






]

oem_numbers = ['3084980']

# Range of years
years = list(range(1998, 2003))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#       Make             Model Vendor Code                   Vendor Name  \
# 0  POLARIS  Big Boss 500 6x6        NACH  NACHMAN INTERNATIONAL CO.LTD
# 1  POLARIS  Big Boss 500 6x6        NACH  NACHMAN INTERNATIONAL CO.LTD
# 2  POLARIS  Big Boss 500 6x6        NACH  NACHMAN INTERNATIONAL CO.LTD
# 3  POLARIS  Big Boss 500 6x6        NACH  NACHMAN INTERNATIONAL CO.LTD
# 4  POLARIS  Big Boss 500 6x6        NACH  NACHMAN INTERNATIONAL CO.LTD
#
#          MPN AD Item Number                                     Vendor Notes  \
# 0  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 1  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 2  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 3  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 4  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
#
#    REF#     OEM#  Year
# 0  <NA>  3084980  1998
# 1  <NA>  3084980  1999
# 2  <NA>  3084980  2000
# 3  <NA>  3084980  2001
# 4  <NA>  3084980  2002

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\24.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Sportsman 800 EFI 6x6 Big Boss',
'Sportsman 800 6x6 Big Boss',
'Sportsman 570 Big Boss 6x6 EPS'






]

oem_numbers = ['3084980']

# Range of years
years = list(range(2000, 2009))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#        Make                           Model Vendor Code  \
# 0   POLARIS  Sportsman 800 EFI 6x6 Big Boss        NACH
# 1   POLARIS      Sportsman 800 6x6 Big Boss        NACH
# 2   POLARIS  Sportsman 570 Big Boss 6x6 EPS        NACH
# 3   POLARIS  Sportsman 800 EFI 6x6 Big Boss        NACH
# 4   POLARIS      Sportsman 800 6x6 Big Boss        NACH
# 5   POLARIS  Sportsman 570 Big Boss 6x6 EPS        NACH
# 6   POLARIS  Sportsman 800 EFI 6x6 Big Boss        NACH
# 7   POLARIS      Sportsman 800 6x6 Big Boss        NACH
# 8   POLARIS  Sportsman 570 Big Boss 6x6 EPS        NACH
# 9   POLARIS  Sportsman 800 EFI 6x6 Big Boss        NACH
# 10  POLARIS      Sportsman 800 6x6 Big Boss        NACH
# 11  POLARIS  Sportsman 570 Big Boss 6x6 EPS        NACH
# 12  POLARIS  Sportsman 800 EFI 6x6 Big Boss        NACH
# 13  POLARIS      Sportsman 800 6x6 Big Boss        NACH
# 14  POLARIS  Sportsman 570 Big Boss 6x6 EPS        NACH
# 15  POLARIS  Sportsman 800 EFI 6x6 Big Boss        NACH
# 16  POLARIS      Sportsman 800 6x6 Big Boss        NACH
# 17  POLARIS  Sportsman 570 Big Boss 6x6 EPS        NACH
# 18  POLARIS  Sportsman 800 EFI 6x6 Big Boss        NACH
# 19  POLARIS      Sportsman 800 6x6 Big Boss        NACH
# 20  POLARIS  Sportsman 570 Big Boss 6x6 EPS        NACH
# 21  POLARIS  Sportsman 800 EFI 6x6 Big Boss        NACH
# 22  POLARIS      Sportsman 800 6x6 Big Boss        NACH
# 23  POLARIS  Sportsman 570 Big Boss 6x6 EPS        NACH
# 24  POLARIS  Sportsman 800 EFI 6x6 Big Boss        NACH
# 25  POLARIS      Sportsman 800 6x6 Big Boss        NACH
# 26  POLARIS  Sportsman 570 Big Boss 6x6 EPS        NACH
#
#                      Vendor Name        MPN AD Item Number  \
# 0   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 1   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 2   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 3   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 4   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 5   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 6   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 7   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 8   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 9   NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 10  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 11  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 12  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 13  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 14  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 15  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 16  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 17  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 18  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 19  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 20  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 21  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 22  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 23  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 24  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 25  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
# 26  NACHMAN INTERNATIONAL CO.LTD  AT-01320A         128707
#
#                                        Vendor Notes  REF#     OEM#  Year
# 0   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2000
# 1   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2000
# 2   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2000
# 3   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2001
# 4   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2001
# 5   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2001
# 6   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2002
# 7   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2002
# 8   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2002
# 9   W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2003
# 10  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2003
# 11  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2003
# 12  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2004
# 13  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2004
# 14  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2004
# 15  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2005
# 16  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2005
# 17  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2005
# 18  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2006
# 19  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2006
# 20  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2006
# 21  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2007
# 22  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2007
# 23  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2007
# 24  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2008
# 25  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2008
# 26  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>  3084980  2008

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\25.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Magnum 500 4x4',
'Scrambler 500 4x4',
'Sportsman 500 4x4',
'Ranger 4x4 500 EFI'







]

oem_numbers = ['3084980']

# Range of years
years = list(range(2004, 2006))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#       Make               Model Vendor Code                   Vendor Name  \
# 0  POLARIS      Magnum 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 1  POLARIS   Scrambler 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 2  POLARIS   Sportsman 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 3  POLARIS  Ranger 4x4 500 EFI        NACH  NACHMAN INTERNATIONAL CO.LTD
# 4  POLARIS      Magnum 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 5  POLARIS   Scrambler 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 6  POLARIS   Sportsman 500 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 7  POLARIS  Ranger 4x4 500 EFI        NACH  NACHMAN INTERNATIONAL CO.LTD
#
#          MPN AD Item Number                                     Vendor Notes  \
# 0  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 1  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 2  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 3  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 4  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 5  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 6  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
# 7  AT-01320A         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE
#
#    REF#     OEM#  Year
# 0  <NA>  3084980  2004
# 1  <NA>  3084980  2004
# 2  <NA>  3084980  2004
# 3  <NA>  3084980  2004
# 4  <NA>  3084980  2005
# 5  <NA>  3084980  2005
# 6  <NA>  3084980  2005
# 7  <NA>  3084980  2005

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\26.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['UTV'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Ranger 4x4 400'








]

oem_numbers = ['3084980']

# Range of years
years = list(range(2010, 2015))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#   Make           Model Vendor Code                   Vendor Name        MPN  \
# 0  UTV  Ranger 4x4 400        NACH  NACHMAN INTERNATIONAL CO.LTD  AT-01320A
# 1  UTV  Ranger 4x4 400        NACH  NACHMAN INTERNATIONAL CO.LTD  AT-01320A
# 2  UTV  Ranger 4x4 400        NACH  NACHMAN INTERNATIONAL CO.LTD  AT-01320A
# 3  UTV  Ranger 4x4 400        NACH  NACHMAN INTERNATIONAL CO.LTD  AT-01320A
# 4  UTV  Ranger 4x4 400        NACH  NACHMAN INTERNATIONAL CO.LTD  AT-01320A
#
#   AD Item Number                                     Vendor Notes  REF#  \
# 0         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>
# 1         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>
# 2         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>
# 3         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>
# 4         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>
#
#       OEM#  Year
# 0  3084980  2010
# 1  3084980  2011
# 2  3084980  2012
# 3  3084980  2013
# 4  3084980  2014

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\27.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['UTV'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Ranger 2x4 500'








]

oem_numbers = ['3084980']

# Range of years
years = list(range(2008, 2010))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#   Make           Model Vendor Code                   Vendor Name        MPN  \
# 0  UTV  Ranger 2x4 500        NACH  NACHMAN INTERNATIONAL CO.LTD  AT-01320A
# 1  UTV  Ranger 2x4 500        NACH  NACHMAN INTERNATIONAL CO.LTD  AT-01320A
#
#   AD Item Number                                     Vendor Notes  REF#  \
# 0         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>
# 1         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>
#
#       OEM#  Year
# 0  3084980  2008
# 1  3084980  2009

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\28.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['UTV'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Ranger 2x4 500',
'Ranger 4x4 500'









]

oem_numbers = ['3084980']

# Range of years
years = list(range(2004, 2009))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#   Make           Model Vendor Code                   Vendor Name        MPN  \
# 0  UTV  Ranger 2x4 500        NACH  NACHMAN INTERNATIONAL CO.LTD  AT-01320A
# 1  UTV  Ranger 4x4 500        NACH  NACHMAN INTERNATIONAL CO.LTD  AT-01320A
# 2  UTV  Ranger 2x4 500        NACH  NACHMAN INTERNATIONAL CO.LTD  AT-01320A
# 3  UTV  Ranger 4x4 500        NACH  NACHMAN INTERNATIONAL CO.LTD  AT-01320A
# 4  UTV  Ranger 2x4 500        NACH  NACHMAN INTERNATIONAL CO.LTD  AT-01320A
# 5  UTV  Ranger 4x4 500        NACH  NACHMAN INTERNATIONAL CO.LTD  AT-01320A
# 6  UTV  Ranger 2x4 500        NACH  NACHMAN INTERNATIONAL CO.LTD  AT-01320A
# 7  UTV  Ranger 4x4 500        NACH  NACHMAN INTERNATIONAL CO.LTD  AT-01320A
# 8  UTV  Ranger 2x4 500        NACH  NACHMAN INTERNATIONAL CO.LTD  AT-01320A
# 9  UTV  Ranger 4x4 500        NACH  NACHMAN INTERNATIONAL CO.LTD  AT-01320A
#
#   AD Item Number                                     Vendor Notes  REF#  \
# 0         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>
# 1         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>
# 2         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>
# 3         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>
# 4         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>
# 5         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>
# 6         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>
# 7         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>
# 8         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>
# 9         128707  W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE  <NA>
#
#       OEM#  Year
# 0  3084980  2004
# 1  3084980  2004
# 2  3084980  2005
# 3  3084980  2005
# 4  3084980  2006
# 5  3084980  2006
# 6  3084980  2007
# 7  3084980  2007
# 8  3084980  2008
# 9  3084980  2008

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 01\Spark Plug Tools\MERGE\29.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['UTV'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-01320A'], 
         'AD Item Number': ['128707'], 
         'Vendor Notes': ['W/ WIRE 60 CM, RESISTOR 5KΩ, MATERIAL: EPD+WIRE'], 
         'REF#': [pd.NA], 
         'OEM#': ['3084980']}

# List of models
new_list_models = [
'Ranger 6x6 500'










]

oem_numbers = ['3084980']

# Range of years
years = list(range(2004, 2009))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
